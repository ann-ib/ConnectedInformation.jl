# %% [markdown]
# # Connected information results for DMN data
#
# Total correlation: $$I_N = \sum_iH(X_i) - H(X)$$
#
# ### Diskretization to 2 values
#
# - Data
#
# |Order|Entropy upper approx|Connected information lower|$$I_C/I_N$$ lower|
# |-----|--------------------|---------------------------|-----------------|
# | 1   | 10                 | X                         | X               |
# | 2   | 8.6279             | 1.3721                    | 0.6532          |
# | 3   | 8.6051             | 0.0228                    | 0.0108          |
# | 4   | 8.2759             | 0.3292                    | 0.1567          |
# | 5   | 8.2759             | 0                         | 0               |
# | 6   | 8.1294             | 0.1465                    | 0.0697          |
# | 7   | 8.1294             | 0                         | 0               |
# | 8   | 8.1185             | 0.0109                    | 0.0051          |
# | 9   | 8.1185             | 0                         | 0               |
# | 10  | 7.8994             | 0.2191                    | 0.1043          |
#
# $
# \begin{aligned}
# &I_N = 10 - 7.8994 = 2.1006
# \end{aligned}
# $
#
# - Surrogate
#
# |Order|Entropy upper approx|Connected information lower|$$I_C/I_N$$ lower|
# |-----|--------------------|---------------------------|-----------------|
# | 1   | 10                 | X                         | X               |
# | 2   | 8.6614             | 1.3386                    | 0.6484          |
# | 3   | 8.6332             | 0.0282                    | 0.0136          |
# | 4   | 8.3078             | 0.3254                    | 0.1576          |
# | 5   | 8.3036             | 0.0042                    | 0.0020          |
# | 6   | 8.1673             | 0.1363                    | 0.0660          |
# | 7   | 8.1673             | 0                         | 0               |
# | 8   | 8.1567             | 0.0105                    | 0.0050          |
# | 9   | 8.1567             | 0                         | 0               |
# | 10  | 7.9356             | 0.2211                    | 0.1071          |
#
# $
# \begin{aligned}
# &I_N = 10 - 7.9356 = 2.0644
# \end{aligned}
# $
#
# ### Diskretization to 3 values
#
# - Data
#
# |Order|Entropy upper approx|Connected information lower|$$I_C/I_N$$ lower|
# |-----|--------------------|---------------------------|-----------------|
# | 1   | 15.8496            | X                         | X               |
# | 2   | 13.7165            | 2.1332                    | 0.5745          |
# | 3   | 13.6892            | 0.0272                    | 0.0073          |
# | 4   | 13.2019            | 0.4874                    | 0.1312          |
# | 5   | 13.2019            | 0                         | 0               |
# | 6   | 12.9753            | 0.2265                    | 0.0610          |
# | 7   | 12.9753            | 0                         | 0               |
# | 8   | 12.8566            | 0.1188                    | 0.0319          |
# | 9   | 12.7815            | 0.0750                    | 0.0202          |
# | 10  | 12.1370            | 0.6446                    | 0.1736          |
#
# $
# \begin{aligned}
# &I_N = 15.8496 - 12.1370 = 3.7126
# \end{aligned}
# $
#
# - Surrogate
#
# |Order|Entropy upper approx|Connected information lower|$$I_C/I_N$$ lower|
# |-----|--------------------|---------------------------|-----------------|
# | 1   | 15.8496            | X                         | X               |
# | 2   | 13.7436            | 2.1060                    | 0.5736          |
# | 3   | 13.7159            | 0.0277                    | 0.0075          |
# | 4   | 13.2212            | 0.4947                    | 0.1345          |
# | 5   | 13.2212            | 0                         | 0               |
# | 6   | 13.001             | 0.2201                    | 0.0598          |
# | 7   | 13.001             | 0                         | 0               |
# | 8   | 12.8976            | 0.1035                    | 0.0281          |
# | 9   | 12.8039            | 0.0937                    | 0.0254          |
# | 10  | 12.1719            | 0.6320                    | 0.1718          |
#
# $
# \begin{aligned}
# &I_N = 15.8496 - 12.1719 = 3.6777
# \end{aligned}
# $
#
# ### Diskretization to 4 values
#
# - Data
#
# |Order|Entropy upper approx|Connected information lower|$$I_C/I_N$$ lower|
# |-----|--------------------|---------------------------|-----------------|
# | 1   | 20                 | X                         | X               |
# | 2   | 17.4319            | 2.5681                    | 0.4280          |
# | 3   | 17.3955            | 0.0363                    | 0.0060          |
# | 4   | 16.8198            | 0.5757                    | 0.0959          |
# | 5   | 16.8011            | 0.0188                    | 0.0031          |
# | 6   | 16.5000            | 0.3011                    | 0.0501          |
# | 7   | 16.5000            | 0                         | 0               |
# | 8   | 15.9454            | 0.5546                    | 0.0924          |
# | 9   | 15.3893            | 0.5561                    | 0.0926          |
# | 10  | 13.9999            | 1.3895                    | 0.2316          |
#
# $
# \begin{aligned}
# &I_N = 20 - 13.9999 = 6
# \end{aligned}
# $
#
# - Surrogate
#
# |Order|Entropy upper approx|Connected information lower|$$I_C/I_N$$ lower|
# |-----|--------------------|---------------------------|-----------------|
# | 1   | 20                 | X                         | X               |
# | 2   | 17.4605            | 2.5395                    | 0.4256          |
# | 3   | 17.4340            | 0.0264                    | 0.0044          |
# | 4   | 16.8534            | 0.5806                    | 0.0972          |
# | 5   | 16.8387            | 0.0147                    | 0.0024          |
# | 6   | 16.5431            | 0.2956                    | 0.0495          |
# | 7   | 16.5431            | 0                         | 0               |
# | 8   | 15.9988            | 0.5443                    | 0.0912          |
# | 9   | 15.4262            | 0.5726                    | 0.0959          |
# | 10  | 14.0325            | 1.3937                    | 0.2335          |
#
# $
# \begin{aligned}
# &I_N = 20 - 14.0325 = 5.9675
# \end{aligned}
# $
